# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib as mpt
from lightgbm import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('C:Desktop/data.csv',encoding='GBK')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
#y_train=data.status
#data.drop(['status'],axis=1,inplace=True)

# %%
#去掉重复的
data_cols=data.columns.values.tolist()
for col in data_cols:
    if data[col].value_counts().count()==1 :
        data.drop(col,axis=1,inplace=True)
data.drop(['id_name','trade_no','custid'],axis=1,inplace=True)
     
reg_preference_for_trad_mapping={
    '一线城市':1,
    '二线城市':2,
    '三线城市':3,
    '境外':4,
    '其他城市':5
}
data.reg_preference_for_trad=data.reg_preference_for_trad.map(reg_preference_for_trad_mapping)
data.reg_preference_for_trad.fillna(stats.mode(data.reg_preference_for_trad)[0][0],inplace=True)

data.latest_query_time=pd.to_datetime(data.latest_query_time)
data['latest_query_time_year']=data.latest_query_time.dt.year
data['latest_query_time_month']=data.latest_query_time.dt.month
data['latest_query_time_day']=data.latest_query_time.dt.day
data.loans_latest_time=pd.to_datetime(data.loans_latest_time)
data['loans_latest_time_year']=data.loans_latest_time.dt.year
data['loans_latest_time_month']=data.loans_latest_time.dt.month
data['loans_latest_time_day']=data.loans_latest_time.dt.day
data.drop(['latest_query_time','loans_latest_time'],axis=1,inplace=True)

# %%
data.student_feature.fillna('0',inplace=True)
data.dropna(thresh=80,inplace=True)
data.fillna(data.median(),inplace=True)

# %%
data.student_feature=data.student_feature.astype('int64')

# %%
y_data=data.status
data.drop('status',axis=1,inplace=True)
x_train,x_test,y_train,y_test=train_test_split(data,y_data,test_size=0.3,random_state=2018)
x_test.head()
# Out:
#       Unnamed: 0  low_volume_percent  middle_volume_percent  \
# 1131        2944                0.02                   0.88
# 3410        8586                0.09                   0.91
# 366          898                0.00                   0.54
# 4084       10317                0.04                   0.96
# 440         1077                0.02                   0.86
#
#       take_amount_in_later_12_month_highest  \
# 1131                                   8500
# 3410                                    400
# 366                                       0
# 4084                                    500
# 440                                   20000
#
#       trans_amount_increase_rate_lately  trans_activity_month  \
# 1131                               1.76                  1.00
# 3410                               1.14                  0.52
# 366                                1.03                  0.86
# 4084                               0.62                  0.68
# 440                                1.58                  0.92
#
#       trans_activity_day  transd_mcc  trans_days_interval_filter  \
# 1131               0.741        28.0                         9.0
# 3410               0.242        16.0                        85.0
# 366                0.297        14.0                        23.0
# 4084               0.233        19.0                        23.0
# 440                0.569        29.0                        12.0
#
#       trans_days_interval  regional_mobility student_feature  \
# 1131                  8.0                3.0               1
# 3410                 69.0                4.0               0
# 366                  27.0                3.0               0
# 4084                 17.0                4.0               0
# 440                  12.0                2.0               0
#
#       repayment_capability  is_high_user  number_of_trans_from_2011  \
# 1131                 31870             0                       31.0
# 3410                  5650             0                       32.0
# 366                  31060             0                       25.0
# 4084                  5310             0                       39.0
# 440                   9790             0                       33.0
#
#       first_transaction_time  historical_trans_amount  historical_trans_day  \
# 1131              20150814.0                   717700                 486.0
# 3410              20130101.0                    59450                 126.0
# 366               20151031.0                   173520                 145.0
# 4084              20130602.0                    58330                 146.0
# 440               20150328.0                   375420                 399.0
#
#       rank_trad_1_month  trans_amount_3_month  \
# 1131               0.25                 60730
# 3410               0.70                   690
# 366                0.55                 25250
# 4084               0.65                  5850
# 440                0.20                 56240
#
#       avg_consume_less_12_valid_month    abs  top_trans_count_last_1_month  \
# 1131                              6.0  36950                          0.05
# 3410                              6.0   4660                          1.00
# 366                               6.0  36870                          0.65
# 4084                              7.0   1210                          0.40
# 440                               7.0  19140                          0.05
#
#       avg_price_last_12_month  avg_price_top_last_12_valid_month  \
# 1131                     1040                               0.55
# 3410                      490                               0.70
# 366                      2950                               0.30
# 4084                      770                               0.60
# 440                      1330                               0.50
#
#       reg_preference_for_trad  trans_top_time_last_1_month  \
# 1131                      3.0                          8.0
# 3410                      1.0                          0.0
# 366                       3.0                          5.0
# 4084                      3.0                         10.0
# 440                       1.0                          6.0
#
#       trans_top_time_last_6_month  consume_top_time_last_1_month  \
# 1131                          8.0                            8.0
# 3410                         85.0                            0.0
# 366                          23.0                            5.0
# 4084                         18.0                           10.0
# 440                          10.0                            6.0
#
#       consume_top_time_last_6_month  cross_consume_count_last_1_month  \
# 1131                            8.0                               1.0
# 3410                           90.0                               0.0
# 366                            23.0                               0.0
# 4084                           18.0                               0.0
# 440                            10.0                               3.0
#
#       trans_fail_top_count_enum_last_1_month  \
# 1131                                     0.0
# 3410                                     1.0
# 366                                      0.0
# 4084                                     1.0
# 440                                      1.0
#
#       trans_fail_top_count_enum_last_6_month  \
# 1131                                     3.0
# 3410                                     1.0
# 366                                      1.0
# 4084                                     4.0
# 440                                      5.0
#
#       trans_fail_top_count_enum_last_12_month  consume_mini_time_last_1_month  \
# 1131                                      3.0                            27.0
# 3410                                      2.0                             0.0
# 366                                       2.0                             0.0
# 4084                                      4.0                             0.0
# 440                                       5.0                            35.0
#
#       max_cumulative_consume_later_1_month  max_consume_count_later_6_month  \
# 1131                                  2000                             18.0
# 3410                                   650                              1.0
# 366                                   1050                              2.0
# 4084                                   500                              2.0
# 440                                   4120                              6.0
#
#       railway_consume_count_last_12_month  \
# 1131                                  0.0
# 3410                                  0.0
# 366                                   0.0
# 4084                                  1.0
# 440                                   0.0
#
#       pawns_auctions_trusts_consume_last_1_month  \
# 1131                                         280
# 3410                                           0
# 366                                         1050
# 4084                                           0
# 440                                          440
#
#       pawns_auctions_trusts_consume_last_6_month  \
# 1131                                       27950
# 3410                                           0
# 366                                        58780
# 4084                                          80
# 440                                        30890
#
#       jewelry_consume_count_last_6_month  first_transaction_day  \
# 1131                                 0.0                 1011.0
# 3410                                 0.0                 1966.0
# 366                                  0.0                  933.0
# 4084                                 0.0                 1814.0
# 440                                  0.0                 1150.0
#
#       trans_day_last_12_month  apply_score  apply_credibility  \
# 1131                     82.0        638.0               79.0
# 3410                     83.0        531.0               75.0
# 366                      95.0        531.0               83.0
# 4084                     82.0        609.0               74.0
# 440                      82.0        545.0               75.0
#
#       query_org_count  query_finance_count  query_cash_count  query_sum_count  \
# 1131              8.0                  5.0               3.0             10.0
# 3410              4.0                  3.0               1.0              6.0
# 366               2.0                  1.0               1.0              3.0
# 4084              4.0                  2.0               1.0              5.0
# 440              10.0                  4.0               3.0             12.0
#
#       latest_one_month_apply  latest_three_month_apply  \
# 1131                     2.0                       5.0
# 3410                     2.0                       4.0
# 366                      1.0                       2.0
# 4084                     0.0                       0.0
# 440                      7.0                       9.0
#
#       latest_six_month_apply  loans_score  loans_credibility_behavior  \
# 1131                     5.0        603.0                        76.0
# 3410                     6.0        486.0                        77.0
# 366                      2.0        495.0                        75.0
# 4084                     1.0        584.0                        83.0
# 440                      9.0        516.0                        78.0
#
#       loans_count  loans_settle_count  loans_overdue_count  \
# 1131         71.0                71.0                  0.0
# 3410          8.0                 6.0                  1.0
# 366          13.0                13.0                  1.0
# 4084          8.0                 7.0                  0.0
# 440          46.0                40.0                  1.0
#
#       loans_org_count_behavior  consfin_org_count_behavior  loans_cash_count  \
# 1131                      20.0                         5.0              15.0
# 3410                       5.0                         2.0               3.0
# 366                        4.0                         0.0               4.0
# 4084                       4.0                         0.0               4.0
# 440                       17.0                         9.0               8.0
#
#       latest_one_month_loan  latest_three_month_loan  latest_six_month_loan  \
# 1131                    0.0                      1.0                   26.0
# 3410                    0.0                      1.0                    4.0
# 366                     0.0                      0.0                    3.0
# 4084                    0.0                      0.0                    1.0
# 440                     2.0                      4.0                   13.0
#
#       history_suc_fee  history_fail_fee  latest_one_month_suc  \
# 1131            101.0               2.0                   0.0
# 3410              6.0               3.0                   0.0
# 366              14.0               0.0                   0.0
# 4084              8.0               1.0                   0.0
# 440              66.0              14.0                   1.0
#
#       latest_one_month_fail  loans_long_time  loans_credit_limit  \
# 1131                    0.0            338.0              2200.0
# 3410                    0.0            298.0               700.0
# 366                     0.0            353.0              3200.0
# 4084                    0.0            334.0              1300.0
# 440                     2.0            351.0              2600.0
#
#       loans_credibility_limit  loans_org_count_current  loans_product_count  \
# 1131                     76.0                     15.0                 15.0
# 3410                     78.0                      3.0                  3.0
# 366                      75.0                      4.0                  4.0
# 4084                     83.0                      4.0                  5.0
# 440                      75.0                      8.0                  9.0
#
#       loans_max_limit  loans_avg_limit  consfin_credit_limit  \
# 1131           5000.0           1966.0               21700.0
# 3410           1000.0            666.0                4400.0
# 366            5400.0           2900.0                   0.0
# 4084           2000.0           1250.0                   0.0
# 440            4000.0           1612.0               15600.0
#
#       consfin_credibility  consfin_org_count_current  consfin_product_count  \
# 1131                 79.0                        5.0                    5.0
# 3410                 77.0                        2.0                    3.0
# 366                   0.0                        0.0                    0.0
# 4084                  0.0                        0.0                    0.0
# 440                  80.0                        9.0                   10.0
#
#       consfin_max_limit  consfin_avg_limit  latest_query_day  \
# 1131            49200.0            24000.0              17.0
# 3410             5400.0             3600.0              12.0
# 366                 0.0                0.0              27.0
# 4084                0.0                0.0             135.0
# 440             36600.0            15533.0              20.0
#
#       loans_latest_day  latest_query_time_year  latest_query_time_month  \
# 1131              68.0                  2018.0                      4.0
# 3410              71.0                  2018.0                      4.0
# 366              124.0                  2018.0                      4.0
# 4084             177.0                  2017.0                     12.0
# 440               27.0                  2018.0                      4.0
#
#       latest_query_time_day  loans_latest_time_year  loans_latest_time_month  \
# 1131                   20.0                  2018.0                      2.0
# 3410                   22.0                  2018.0                      2.0
# 366                    10.0                  2018.0                      1.0
# 4084                   23.0                  2017.0                     11.0
# 440                    14.0                  2018.0                      4.0
#
#       loans_latest_time_day
# 1131                   28.0
# 3410                   22.0
# 366                     3.0
# 4084                   11.0
# 440                     7.0

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
#parameters={'max_depth':range(1,10,3),'n_estimators':[100,200,300]}
#forest = RandomForestClassifier(mini_samples_leaf=3,random_state=1,n_jobs=1)
#reserchCV=GridSearchCV(forest,parameters,cv=3)
#forest.fit(x_train,y_train)
#

# %%
RF = RandomForestClassifier(max_depth=7,n_estimators=300,min_samples_leaf=3,random_state=1,n_jobs=1)
SelectFromModel(RF)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4423 entries, 0 to 4753
# Data columns (total 88 columns):
# Unnamed: 0                                    4423 non-null int64
# low_volume_percent                            4423 non-null float64
# middle_volume_percent                         4423 non-null float64
# take_amount_in_later_12_month_highest         4423 non-null int64
# trans_amount_increase_rate_lately             4423 non-null float64
# trans_activity_month                          4423 non-null float64
# trans_activity_day                            4423 non-null float64
# transd_mcc                                    4423 non-null float64
# trans_days_interval_filter                    4423 non-null float64
# trans_days_interval                           4423 non-null float64
# regional_mobility                             4423 non-null float64
# student_feature                               4423 non-null int64
# repayment_capability                          4423 non-null int64
# is_high_user                                  4423 non-null int64
# number_of_trans_from_2011                     4423 non-null float64
# first_transaction_time                        4423 non-null float64
# historical_trans_amount                       4423 non-null int64
# historical_trans_day                          4423 non-null float64
# rank_trad_1_month                             4423 non-null float64
# trans_amount_3_month                          4423 non-null int64
# avg_consume_less_12_valid_month               4423 non-null float64
# abs                                           4423 non-null int64
# top_trans_count_last_1_month                  4423 non-null float64
# avg_price_last_12_month                       4423 non-null int64
# avg_price_top_last_12_valid_month             4423 non-null float64
# reg_preference_for_trad                       4423 non-null float64
# trans_top_time_last_1_month                   4423 non-null float64
# trans_top_time_last_6_month                   4423 non-null float64
# consume_top_time_last_1_month                 4423 non-null float64
# consume_top_time_last_6_month                 4423 non-null float64
# cross_consume_count_last_1_month              4423 non-null float64
# trans_fail_top_count_enum_last_1_month        4423 non-null float64
# trans_fail_top_count_enum_last_6_month        4423 non-null float64
# trans_fail_top_count_enum_last_12_month       4423 non-null float64
# consume_mini_time_last_1_month                4423 non-null float64
# max_cumulative_consume_later_1_month          4423 non-null int64
# max_consume_count_later_6_month               4423 non-null float64
# railway_consume_count_last_12_month           4423 non-null float64
# pawns_auctions_trusts_consume_last_1_month    4423 non-null int64
# pawns_auctions_trusts_consume_last_6_month    4423 non-null int64
# jewelry_consume_count_last_6_month            4423 non-null float64
# first_transaction_day                         4423 non-null float64
# trans_day_last_12_month                       4423 non-null float64
# apply_score                                   4423 non-null float64
# apply_credibility                             4423 non-null float64
# query_org_count                               4423 non-null float64
# query_finance_count                           4423 non-null float64
# query_cash_count                              4423 non-null float64
# query_sum_count                               4423 non-null float64
# latest_one_month_apply                        4423 non-null float64
# latest_three_month_apply                      4423 non-null float64
# latest_six_month_apply                        4423 non-null float64
# loans_score                                   4423 non-null float64
# loans_credibility_behavior                    4423 non-null float64
# loans_count                                   4423 non-null float64
# loans_settle_count                            4423 non-null float64
# loans_overdue_count                           4423 non-null float64
# loans_org_count_behavior                      4423 non-null float64
# consfin_org_count_behavior                    4423 non-null float64
# loans_cash_count                              4423 non-null float64
# latest_one_month_loan                         4423 non-null float64
# latest_three_month_loan                       4423 non-null float64
# latest_six_month_loan                         4423 non-null float64
# history_suc_fee                               4423 non-null float64
# history_fail_fee                              4423 non-null float64
# latest_one_month_suc                          4423 non-null float64
# latest_one_month_fail                         4423 non-null float64
# loans_long_time                               4423 non-null float64
# loans_credit_limit                            4423 non-null float64
# loans_credibility_limit                       4423 non-null float64
# loans_org_count_current                       4423 non-null float64
# loans_product_count                           4423 non-null float64
# loans_max_limit                               4423 non-null float64
# loans_avg_limit                               4423 non-null float64
# consfin_credit_limit                          4423 non-null float64
# consfin_credibility                           4423 non-null float64
# consfin_org_count_current                     4423 non-null float64
# consfin_product_count                         4423 non-null float64
# consfin_max_limit                             4423 non-null float64
# consfin_avg_limit                             4423 non-null float64
# latest_query_day                              4423 non-null float64
# loans_latest_day                              4423 non-null float64
# latest_query_time_year                        4423 non-null float64
# latest_query_time_month                       4423 non-null float64
# latest_query_time_day                         4423 non-null float64
# loans_latest_time_year                        4423 non-null float64
# loans_latest_time_month                       4423 non-null float64
# loans_latest_time_day                         4423 non-null float64
# dtypes: float64(76), int64(12)
# memory usage: 3.2 MB

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline,FeatureUnion
lgb=lightgbm.LGBMClassifier(boosting_type='gbdt', max_depth=-1, learning_rate=0.01, n_estimators=2000,
                            subsample_for_bin=50000, objective='binary', min_split_gain=0,
                           min_child_weight=5, min_child_samples=10, subsample=0.8, subsample_freq=1,
                           colsample_bytree=1,reg_alpha =3, reg_lambda=5, seed=1000, n_jobs=10, silent=True)
features_union=SelectFromModel(RF)
pipeline=Pipeline([('features',features_union),('lgb',lgb)])
params=dict(lgb__num_leaves=[25,35])
res=GridSearchCV(pipeline,params,cv=3)
res.fit(x_train_scaled,y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('features', SelectFromModel(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_spl... seed=1000,
#         silent=True, subsample=0.8, subsample_for_bin=50000,
#         subsample_freq=1))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'lgb__num_leaves': [25, 35]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring=None, verbose=0)

# %%
res.best_score_
# Out:
# 0.8032945736434108
